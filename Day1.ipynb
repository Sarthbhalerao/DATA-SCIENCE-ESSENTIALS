# %% [markdown]
# # **ANSWER 1**

# %%
print("RAINBOW")
# Out:
# RAINBOW

# %% [markdown]
# # **ANSWER 2**

# %%
print("LETS UPGRADE")
# Out:
# LETS UPGRADE

# %% [markdown]
# # **ANSWER 3 and 4**

# %%
cp=input()   #cost price
sp=input()   #selling price
if cp>sp:
   print("Loss")
elif sp>cp:
    print("Profit")
else :
    print("Neither")
# Out:
# 20
# 30
# Profit

# %% [markdown]
# # **ANSWER 5**

# %%
Euros = float(input("Euros:"))
Rupees =Euros * 80
print(Rupees, " Rupees")
# Out:
# Euros:20
# 1600.0  Rupees
